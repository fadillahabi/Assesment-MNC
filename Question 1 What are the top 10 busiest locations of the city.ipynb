# %%
import pandas as pd

# %%
data = pd.read_csv("trip_data_4.csv")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head(100)
# Out:
#                            medallion                      hack_license  \
# 0   91F6EB84975BBC867E32CB113C7C2CD5  AD8751110E6292079EB10EB9481FE1A6
# 1   EC34CD1B3797DFAFF3FE099BA87B6656  8FE6A4AEDF89B6B4E19D2377FD3FB7D7
# 2   C1B9DA774DC2BBC6DE27CE994E7F44A0  E1B595FD55E4C82C1E213EB17438107A
# 3   9BA84250355AB3FC031C9252D395BF8A  16BB0D96A0DCC853AEC7F55C8D6C71E0
# 4   205A696DF62AD03C88DA8C5EC5248639  579C41EA5EC846F8B641A42F9EE3E855
# ..                               ...                               ...
# 95  76E1DDD13AE255EF20FB0981785CFF56  1A87AFEAF234870853D8DAD919B13E4D
# 96  A90592AD2209B507D8ACC34D4B556BEC  FFA48277CB44F9F843304288406CBACA
# 97  AB80E0F46504CB0CF484213D85B7491A  3F1FA1F28FDA172CBA7AA740D758191F
# 98  157E792C9A2041556B50C006B2C44594  5AE2BD64DE046BC5C22AFAD51446AC05
# 99  1B9F450C184C13F13B8F92DA11F0B95B  97506FE51C243D4375362A16975BB5CE
#
#     vendor_id   rate_code  store_and_fwd_flag      pickup_datetime  \
# ...

# %%
data.groupby([' pickup_longitude', ' pickup_latitude']).agg({' pickup_datetime':'count'}).sort_values(by=' pickup_datetime', ascending=False).reset_index().head(10)

#[' pickup_datetime', ' pickup_longitude', ' pickup_latitude']
# Out:
#     pickup_longitude   pickup_latitude   pickup_datetime
# 0           0.000000          0.000000            250458
# 1         -74.023048         40.765991              6859
# 2         -73.949043         40.744915               853
# 3         -73.990944         40.736053               853
# 4         -73.917358         40.670559               391
# 5           0.000000         41.453693               251
# 6         -73.883629         40.632210               239
# 7         -74.195213         40.548466               157
# 8           0.000000         40.754341               145
# 9         -73.965012         40.755657               130

# %%
data.groupby([' dropoff_longitude', ' dropoff_latitude']).agg({' pickup_datetime':'count'}).sort_values(by=' pickup_datetime', ascending=False).reset_index().head(10)
# Out:
#     dropoff_longitude   dropoff_latitude   pickup_datetime
# 0            0.000000           0.000000            258783
# 1          -74.023048          40.765991              7045
# 2          -73.990944          40.736053               853
# 3          -73.949043          40.744915               853
# 4          -73.917358          40.670559               390
# 5          -73.883629          40.632210               239
# 6            0.000000          41.453693               233
# 7          -74.195213          40.548466               157
# 8            0.000000          40.754341               150
# 9          -73.965012          40.755657               129
